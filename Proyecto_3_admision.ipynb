# %% [markdown]
# <a href="https://colab.research.google.com/github/ajimenez-gh/cursophyton25/blob/main/Proyecto_3_admision.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd

ruta_archivo = '/content/drive/MyDrive/Colab Data/applicant_list_7.txt'

nombres_columnas = ['Nombre','Apellido','EPH','ECH','EMA','ECS','ESP','OP1','OP2','OP3']

df = pd.read_csv(ruta_archivo, sep=' ', names=nombres_columnas)
df
# Out:
#        Nombre   Apellido  EPH  ECH  EMA  ECS  ESP          OP1          OP2  \
# 0     Jermine    Brunton   84   81   73   92   48      Physics  Engineering
# 1       Justo     Mirfin   71   77   61   60   41  Engineering      Biotech
# 2        Uzma  Naysmythe   60   94   75   71   80    Chemistry  Engineering
# 3       Koury      Wingo   71   81   81   83   59  Engineering      Biotech
# 4    Kentrell  Hillhouse   40   69   42   58   20  Mathematics  Engineering
# ..        ...        ...  ...  ...  ...  ...  ...          ...          ...
# 93     Tamkia       Fish   81   71   73   86   78      Physics  Engineering
# 94      Deniz  Blanchard   71   77   61   60   61  Engineering      Biotech
# 95       Mira      Riley   60   94   75   71   80  Engineering      Biotech
# 96      Loura    Macansh   71   81   81   93   79  Engineering      Physics
# 97  Nastassja   Trustram   60   49   82   68   70  Mathematics  Engineering
#
#             OP3
# 0   Mathematics
# 1     Chemistry
# ...

# %%
print(df.shape)
df.info()
display(df[['OP1', OP2','OP3']])
# Out:
#   File "/tmp/ipython-input-3976588444.py", line 3
#     display(df[['OP1', OP2','OP3']])
#                                 ^
# SyntaxError: unterminated string literal (detected at line 3)

# %%
df['nombre_completo'] = df['Nombre'] + ' ' + df['Apellido']
df
# Out:
#        Nombre   Apellido  EPH  ECH  EMA  ECS  ESP          OP1          OP2  \
# 0     Jermine    Brunton   84   81   73   92   48      Physics  Engineering
# 1       Justo     Mirfin   71   77   61   60   41  Engineering      Biotech
# 2        Uzma  Naysmythe   60   94   75   71   80    Chemistry  Engineering
# 3       Koury      Wingo   71   81   81   83   59  Engineering      Biotech
# 4    Kentrell  Hillhouse   40   69   42   58   20  Mathematics  Engineering
# ..        ...        ...  ...  ...  ...  ...  ...          ...          ...
# 93     Tamkia       Fish   81   71   73   86   78      Physics  Engineering
# 94      Deniz  Blanchard   71   77   61   60   61  Engineering      Biotech
# 95       Mira      Riley   60   94   75   71   80  Engineering      Biotech
# 96      Loura    Macansh   71   81   81   93   79  Engineering      Physics
# 97  Nastassja   Trustram   60   49   82   68   70  Mathematics  Engineering
#
#             OP3     nombre_completo
# ...

# %%
# definicion de una funcion paraestimar puntaje de admisión
def estimar_puntaje_admision(linea, opcion):
  departamento = linea[opcion]
  if departamento == 'Physics':
    puntaje = (linea['EPH'] + linea['EMA'] + linea['ESP'])/3
  elif departamento == 'Chemistry':
    puntaje = (linea['ECH'] + linea['EPH'] + linea['ESP'])/3
  elif departamento ==  'Mathematics':
    puntaje = (linea['EMA'] + linea['EPH'] + linea['ECH']+ linea['ESP'])/4
  elif departamento ==  'Engineering':
    puntaje = (linea['ECH'] + linea['ECS'] + linea['EPH']+ linea['ESP'])/4
  elif departamento ==  'Biotech':
    puntaje = (linea['EMA'] + linea['ECS'] + linea['ECH']+ linea['ESP'])/4
  else:
    return None
  return round(puntaje,2)

df['OP1_score'] = df.apply(lambda x: estimar_puntaje_admision(x, 'OP1'), axis=1)
df['OP2_score'] = df.apply(lambda x: estimar_puntaje_admision(x, 'OP2'), axis=1)
df['OP3_score'] = df.apply(lambda x: estimar_puntaje_admision(x, 'OP3'), axis=1)
df

display(df)
# Out:
#        Nombre   Apellido  EPH  ECH  EMA  ECS  ESP          OP1          OP2  \
# 0     Jermine    Brunton   84   81   73   92   48      Physics  Engineering
# 1       Justo     Mirfin   71   77   61   60   41  Engineering      Biotech
# 2        Uzma  Naysmythe   60   94   75   71   80    Chemistry  Engineering
# 3       Koury      Wingo   71   81   81   83   59  Engineering      Biotech
# 4    Kentrell  Hillhouse   40   69   42   58   20  Mathematics  Engineering
# ..        ...        ...  ...  ...  ...  ...  ...          ...          ...
# 93     Tamkia       Fish   81   71   73   86   78      Physics  Engineering
# 94      Deniz  Blanchard   71   77   61   60   61  Engineering      Biotech
# 95       Mira      Riley   60   94   75   71   80  Engineering      Biotech
# 96      Loura    Macansh   71   81   81   93   79  Engineering      Physics
# 97  Nastassja   Trustram   60   49   82   68   70  Mathematics  Engineering
#
# ...

# %%
N = int(input("Ingrese el cupo máximo por departamento: "))
departamento_seleccionado = input("Ingrese el departamento a seleccionar: ")
# Out:
# Ingrese el cupo máximo por departamento: 10
# Ingrese el departamento a seleccionar: Biotech

# %%
#filtrado del data para seleccionar departamento
aspirantes_departamento = df[(df['OP1'] == departamento_seleccionado)]

aspirantes_ordenado = aspirantes_departamento.sort_values(by='OP1_score', ascending=False)
aspirantes_ordenado
aspirantes_ordenado.head(N)

tabla_aspirantes_admitidos = pd.DataFrame(

    {
        'nombre_completo': tabla.aspirantes_ordenado['nombre_completo'],
        'OP1_score': tabla.aspirantes_admitidos['OP1_score'],
        'puntaje': tabla_aspirantes_admitidos['OP1_score'],
        'opción': 'OP1'

    }
)
display(tabla_en_formato)


    aspirantes_ordenado.head(N))
tabla_en_formato = pd.DataFrame(tabla_aspirantes_admitidos[['nombre_completo','OP1_score']])
tabla_en_formato
# Out:
#      Nombre     Apellido  EPH  ECH  EMA  ECS  ESP      OP1          OP2  \
# 31   Tawnia       Alcock   81   80   90   72   91  Biotech    Chemistry
# 43    Genee       Mccrae   90   81   80   72   94  Biotech    Chemistry
# 51   Randon     Bradhust   72   88   85   83   59  Biotech  Engineering
# 67  Narissa  Worthington   52   71   80   73   81  Biotech    Chemistry
# 76    Mendy    Macmillan   61   81   81   70   51  Biotech  Engineering
#
#             OP3      nombre_completo  OP1_score  OP2_score  OP3_score
# 31      Physics        Tawnia Alcock      83.25      84.00      87.33
# 43      Physics         Genee Mccrae      81.75      88.33      88.00
# 51    Chemistry      Randon Bradhust      78.75      75.50      73.00
# 67  Mathematics  Narissa Worthington      76.25      68.00        NaN
# 76  Mathematics      Mendy Macmillan      70.75      65.75        NaN
